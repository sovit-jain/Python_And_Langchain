# %% [markdown]
# <a href="https://colab.research.google.com/github/sovit-jain/Python_And_Langchain/blob/python_freedom/Python_Assign1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem Statement:
# A company wants to create a basic system to evaluate employee performance and determine their:
# 1. Bonus amount
# 2. Promotion eligibility
# 3. Training requirement

# %% [markdown]
# Every employee has
# - name
# - yrs_of_experience
# - projects_complted
# - performace_rating
# - skills

# %% [markdown]
# if:
# - experience >= 5 and rating >= 4 -> Eligible for promotion
# - projects completed > 10 or rating >= 4.5 -> eligible for bonus (10,000)
# - if "leadership" not in skills -> Must attend leadership training

# %%
name="Sovit"
yrs_of_experience=14
projects_complted=10
performace_rating=4
skills = ["python", "java", 'communication']
if(yrs_of_experience >= 5 and performace_rating >= 4):
    print("Eligible for promotion")

else:
  print(f"{name} is not eligible for promotion")

if(projects_complted > 10 or performace_rating >= 4.5):
  print(f"{name} is eligible for bonus")

else:
  print(f"{name} is not eligible for bonus")
# Out:
# Eligible for promotion
# Sovit is not eligible for bonus
